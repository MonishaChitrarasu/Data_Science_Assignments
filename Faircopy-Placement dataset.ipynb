# %%
from DescriptiveAnalysis import DescriptiveAnalysis

# %%
import pandas as pd

# %%
obj=DescriptiveAnalysis()

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset['salary']=dataset['salary'].fillna(0)

# %%
quan,qual=obj.quanqual(dataset)

# %%
obj.centraltendency(dataset,quan)
# Out:
#            sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# mean         108  67.3034  66.3332  66.3702  72.1006  62.2782  198702
# median       108       67       65       66       71       62  240000
# mode           1       62       63       65       60     56.7       0
# null           0        0        0        0        0        0       0
# nan            0        0        0        0        0        0       0
# count        215      215      215      215      215      215     215
# min            1    40.89       37       50       50    51.21       0
# 25%         54.5     60.6     60.9       61       60   57.945       0
# 50%          108       67       65       66       71       62  240000
# 75%        161.5     75.7       73       72     83.5   66.255  282500
# 100%         215     89.4     97.7       91       98    77.89  940000
# IQR          107     15.1     12.1       11     23.5     8.31  282500
# ...

# %%
des_data=obj.centraltendency(dataset,quan)

# %%
obj.outliers_range(des_data,quan)
# Out:
# Lesser Range ['hsc_p']
# Greater Range ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# (['hsc_p'], ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'])

# %%
lesser,greater=obj.outliers_range(des_data,quan)
# Out:
# Lesser Range ['hsc_p']
# Greater Range ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
obj.changeoutlier(des_data,dataset,lesser,greater)
obj.centraltendency(dataset,quan)
# Out:
# C:\Users\Madhu\Documents\HOPE\Data Science\DescriptiveAnalysis.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[i][dataset[i]<des_data[i]['Lesser']]=des_data[i]['Lesser']
# C:\Users\Madhu\Documents\HOPE\Data Science\DescriptiveAnalysis.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[j][dataset[j]>des_data[j]['Greater']]=des_data[j]['Greater']
#            sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# mean         108  67.1204  65.6219  66.1191  72.0433  62.0096  192819
# median       108       67       65       66       71       62  240000
# ...
